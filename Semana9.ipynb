# %% [markdown]
# Semana 9 - Explorando dados com o pandas

# %%
import pandas as pd

# %%
arquivo_csv="https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"

# %%
df_titanic = pd.read_csv(arquivo_csv)

# %%
df_titanic
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
df_titanic.describe()
# Out:
#          Survived      Pclass  ...  Parents/Children Aboard       Fare
# count  887.000000  887.000000  ...               887.000000  887.00000
# mean     0.385569    2.305524  ...                 0.383315   32.30542
# std      0.487004    0.836662  ...                 0.807466   49.78204
# min      0.000000    1.000000  ...                 0.000000    0.00000
# 25%      0.000000    2.000000  ...                 0.000000    7.92500
# 50%      0.000000    3.000000  ...                 0.000000   14.45420
# 75%      1.000000    3.000000  ...                 0.000000   31.13750
# max      1.000000    3.000000  ...                 6.000000  512.32920
#
# [8 rows x 6 columns]

# %%
df_titanic['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# Name: Sex, Length: 887, dtype: object

# %%
df_titanic.head(800)
# Out:
#      Survived  Pclass  ... Parents/Children Aboard      Fare
# 0           0       3  ...                       0    7.2500
# 1           1       1  ...                       0   71.2833
# 2           1       3  ...                       0    7.9250
# 3           1       1  ...                       0   53.1000
# 4           0       3  ...                       0    8.0500
# ..        ...     ...  ...                     ...       ...
# 795         0       3  ...                       1   24.1500
# 796         0       2  ...                       0   13.0000
# 797         1       2  ...                       1   26.2500
# 798         1       1  ...                       2  120.0000
# 799         1       3  ...                       1    8.5167
#
# [800 rows x 8 columns]

# %%
df_titanic.tail(10)
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 877         0       3  ...                       0   7.8958
# 878         0       3  ...                       0  10.5167
# 879         0       2  ...                       0  10.5000
# 880         0       3  ...                       0   7.0500
# 881         0       3  ...                       5  29.1250
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [10 rows x 8 columns]

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
df_titanic[ df_titanic['Survived'] ==1 ]
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 8           1       3  ...                       2  11.1333
# 9           1       2  ...                       0  30.0708
# ..        ...     ...  ...                     ...      ...
# 871         1       3  ...                       0   7.2250
# 875         1       1  ...                       1  83.1583
# 876         1       2  ...                       1  26.0000
# 883         1       1  ...                       0  30.0000
# 885         1       1  ...                       0  30.0000
#
# [342 rows x 8 columns]

# %%
print(342/887)
# Out:
# 0.3855693348365276

# %%
pd.set_option('display.max_rows', df_titanic.shape[0]+1)
df_titanic
# Out:
#      Survived  Pclass  ... Parents/Children Aboard      Fare
# 0           0       3  ...                       0    7.2500
# 1           1       1  ...                       0   71.2833
# 2           1       3  ...                       0    7.9250
# 3           1       1  ...                       0   53.1000
# 4           0       3  ...                       0    8.0500
# 5           0       3  ...                       0    8.4583
# 6           0       1  ...                       0   51.8625
# 7           0       3  ...                       1   21.0750
# 8           1       3  ...                       2   11.1333
# 9           1       2  ...                       0   30.0708
# 10          1       3  ...                       1   16.7000
# 11          1       1  ...                       0   26.5500
# 12          0       3  ...                       0    8.0500
# 13          0       3  ...                       5   31.2750
# ...

# %%
pd.set_option('display.max_rows', 50)
df_titanic
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 0           0       3  ...                       0   7.2500
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 4           0       3  ...                       0   8.0500
# ..        ...     ...  ...                     ...      ...
# 882         0       2  ...                       0  13.0000
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
# 885         1       1  ...                       0  30.0000
# 886         0       3  ...                       0   7.7500
#
# [887 rows x 8 columns]

# %%
df_titanic[ df_titanic['Age'] >= df_titanic['Age'].max() ]
# Out:
#      Survived  Pclass  ... Parents/Children Aboard  Fare
# 627         1       1  ...                       0  30.0
#
# [1 rows x 8 columns]

# %%
df_titanic[ df_titanic['Age'] <= df_titanic['Age'].min() ]
# Out:
#      Survived  Pclass  ... Parents/Children Aboard    Fare
# 799         1       3  ...                       1  8.5167
#
# [1 rows x 8 columns]

# %%
df_titanic[df_titanic['Sex'] == 'female']
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 8           1       3  ...                       2  11.1333
# 9           1       2  ...                       0  30.0708
# ..        ...     ...  ...                     ...      ...
# 876         1       2  ...                       1  26.0000
# 878         0       3  ...                       0  10.5167
# 881         0       3  ...                       5  29.1250
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
#
# [314 rows x 8 columns]

# %%
df_titanic[df_titanic['Sex'] == 'female'][df_titanic['Survived'] == 1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 8           1       3  ...                       2  11.1333
# 9           1       2  ...                       0  30.0708
# ..        ...     ...  ...                     ...      ...
# 870         1       2  ...                       0  24.0000
# 871         1       3  ...                       0   7.2250
# 875         1       1  ...                       1  83.1583
# 876         1       2  ...                       1  26.0000
# 883         1       1  ...                       0  30.0000
#
# [233 rows x 8 columns]

# %%
print(233/314)
# Out:
# 0.7420382165605095

# %% [markdown]
# # Parte 2 - Construindo um Dataset

# %%
nome = pd.Series(["Aluno 1", "Aluno 2", "Aluno 3", "Aluno 4"])

# %%
nome
# Out:
# 0    Aluno 1
# 1    Aluno 2
# 2    Aluno 3
# 3    Aluno 4
# dtype: object

# %%
nome[1:3]
# Out:
# 1    Aluno 2
# 2    Aluno 3
# dtype: object

# %% [markdown]
# montando o dataframe

# %%
df_alunos = pd.DataFrame(nome, columns=["Nome"])

# %%
df_alunos
# Out:
#       Nome
# 0  Aluno 1
# 1  Aluno 2
# 2  Aluno 3
# 3  Aluno 4

# %%
df_alunos['AV1'] = [4.0, 5.0, 6.0, 7.0]

# %%
df_alunos
# Out:
#       Nome  AV1
# 0  Aluno 1  4.0
# 1  Aluno 2  5.0
# 2  Aluno 3  6.0
# 3  Aluno 4  7.0

# %%
df_alunos['AV2'] = [9.0, 2.0, 6.0, 4.0]

# %%
df_alunos
# Out:
#       Nome  AV1  AV2
# 0  Aluno 1  4.0  9.0
# 1  Aluno 2  5.0  2.0
# 2  Aluno 3  6.0  6.0
# 3  Aluno 4  7.0  4.0

# %%
df_alunos['media'] =(df_alunos['AV1'] + df_alunos['AV2'])/2
df_alunos
# Out:
#       Nome  AV1  AV2  media
# 0  Aluno 1  4.0  9.0    6.5
# 1  Aluno 2  5.0  2.0    3.5
# 2  Aluno 3  6.0  6.0    6.0
# 3  Aluno 4  7.0  4.0    5.5

# %%
import numpy as np

# %%
df_alunos['resultado'] = np.where(df_alunos['media'] >=6.0, "Aprovado", "Foi para AV3")
df_alunos
# Out:
#       Nome  AV1  AV2  media     resultado
# 0  Aluno 1  4.0  9.0    6.5      Aprovado
# 1  Aluno 2  5.0  2.0    3.5  Foi para AV3
# 2  Aluno 3  6.0  6.0    6.0      Aprovado
# 3  Aluno 4  7.0  4.0    5.5  Foi para AV3

# %% [markdown]
# plotar gráfico

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize=(15,5))

# %%
plt.plot(df_alunos['Nome'], df_alunos['media'])
